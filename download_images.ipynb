# %%
"""
Image Downloader for Photo Dataset
--------------------------------
This script downloads and optimizes images from URLs in a photos.csv file.

Requirements:
    pip install pandas pillow requests tqdm

Usage:
    1. Ensure photos_url.csv is in the same directory as this script
    2. Run the script: python download_images.py
    3. Images will be downloaded to the 'images' folder

Note: 
    - Default image size is 800x800 pixels (maintains aspect ratio)
    - Images are saved as optimized JPEGs
    - You can modify num_images parameter to download fewer images
    - Approximate size of the dataset is 1.5GB and total images are 25,000 images
"""

import pandas as pd
import requests
import os
from PIL import Image
from io import BytesIO
from tqdm import tqdm

def download_images(num_images=None, output_dir="images", target_size=(800, 800)):
    """
    Download and optimize images from photos.csv
    
    Args:
        num_images: Number of images to download (default: all images in CSV)
        output_dir: Directory to save images (default: 'images')
        target_size: Max image dimensions (default: (800, 800))
    """
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Read CSV and prepare dataset
    df = pd.read_csv("photos_url.csv")
    if num_images:
        df = df.head(num_images)
    
    # Download images
    print(f"Downloading {len(df)} images to {output_dir}...")
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        try:
            # Download and save image
            filename = f"{(idx+1):04d}.jpg"
            output_path = os.path.join(output_dir, filename)
            
            response = requests.get(row['photo_image_url'], timeout=10)
            if response.status_code == 200:
                img = Image.open(BytesIO(response.content))
                if img.mode in ('RGBA', 'P'):
                    img = img.convert('RGB')
                img.thumbnail(target_size, Image.Resampling.LANCZOS)
                img.save(output_path, 'JPEG', quality=85, optimize=True)
                
        except Exception as e:
            print(f"Error downloading image {idx+1}")
            continue

if __name__ == "__main__":
    # Download all images (or modify num_images to download fewer)
    download_images(num_images=None)
# Out:
# Downloading 25000 images to images...
#   3%|▎         | 842/25000 [36:05<53:16,  7.56it/s]
# Error downloading image 748
# Error downloading image 749
# Error downloading image 750
# Error downloading image 751
# Error downloading image 752
# Error downloading image 753
# Error downloading image 754
# Error downloading image 755
# Error downloading image 756
# Error downloading image 757
# Error downloading image 758
# Error downloading image 759
# Error downloading image 760
# Error downloading image 761
# Error downloading image 762
# Error downloading image 763
# Error downloading image 764
# Error downloading image 765
# Error downloading image 766
# Error downloading image 767
# Error downloading image 768
# Error downloading image 769
# Error downloading image 770
# Error downloading image 771
# Error downloading image 772
# Error downloading image 773
# Error downloading image 774
# Error downloading image 775
# Error downloading image 776
# Error downloading image 777
# Error downloading image 778
# Error downloading image 779
# Error downloading image 780
# Error downloading image 781
# Error downloading image 782
# Error downloading image 783
# Error downloading image 784
# Error downloading image 785
# Error downloading image 786
# Error downloading image 787
# Error downloading image 788
# Error downloading image 789
# Error downloading image 790
# Error downloading image 791
# Error downloading image 792
# Error downloading image 793
# Error downloading image 794
# Error downloading image 795
# Error downloading image 796
# Error downloading image 797
# Error downloading image 798
# Error downloading image 799
# Error downloading image 800
# Error downloading image 801
# Error downloading image 802
# Error downloading image 803
# Error downloading image 804
# Error downloading image 805
# Error downloading image 806
# Error downloading image 807
# Error downloading image 808
# Error downloading image 809
# Error downloading image 810
# Error downloading image 811
# Error downloading image 812
# Error downloading image 813
# Error downloading image 814
# Error downloading image 815
# Error downloading image 816
# Error downloading image 817
# Error downloading image 818
# Error downloading image 819
# Error downloading image 820
# Error downloading image 821
# Error downloading image 822
# Error downloading image 823
# Error downloading image 824
# Error downloading image 825
# Error downloading image 826
# Error downloading image 827
# Error downloading image 828
# Error downloading image 829
# Error downloading image 830
# Error downloading image 831
# Error downloading image 832
# Error downloading image 833
# Error downloading image 834
# Error downloading image 835
# Error downloading image 836
# Error downloading image 837
# Error downloading image 838
# Error downloading image 839
# Error downloading image 840
# Error downloading image 841
# Error downloading image 842
#   4%|▎         | 937/25000 [36:05<18:04, 22.20it/s]
# Error downloading image 843
# Error downloading image 844
# Error downloading image 845
# Error downloading image 846
# Error downloading image 847
# Error downloading image 848
# Error downloading image 849
# Error downloading image 850
# Error downloading image 851
# Error downloading image 852
# Error downloading image 853
# Error downloading image 854
# Error downloading image 855
# Error downloading image 856
# Error downloading image 857
# Error downloading image 858
# Error downloading image 859
# Error downloading image 860
# Error downloading image 861
# Error downloading image 862
# Error downloading image 863
# Error downloading image 864
# Error downloading image 865
# Error downloading image 866
# Error downloading image 867
# Error downloading image 868
# Error downloading image 869
# Error downloading image 870
# Error downloading image 871
# Error downloading image 872
# Error downloading image 873
# Error downloading image 874
# Error downloading image 875
# Error downloading image 876
# Error downloading image 877
# Error downloading image 878
# Error downloading image 879
# Error downloading image 880
# Error downloading image 881
# Error downloading image 882
# Error downloading image 883
# Error downloading image 884
# Error downloading image 885
# Error downloading image 886
# Error downloading image 887
# Error downloading image 888
# Error downloading image 889
# Error downloading image 890
# Error downloading image 891
# Error downloading image 892
# Error downloading image 893
# Error downloading image 894
# Error downloading image 895
# Error downloading image 896
# Error downloading image 897
# Error downloading image 898
# Error downloading image 899
# Error downloading image 900
# Error downloading image 901
# Error downloading image 902
# Error downloading image 903
# Error downloading image 904
# Error downloading image 905
# Error downloading image 906
# Error downloading image 907
# Error downloading image 908
# Error downloading image 909
# Error downloading image 910
# Error downloading image 911
# Error downloading image 912
# Error downloading image 913
# Error downloading image 914
# Error downloading image 915
# Error downloading image 916
# Error downloading image 917
# Error downloading image 918
# Error downloading image 919
# Error downloading image 920
# Error downloading image 921
# Error downloading image 922
# Error downloading image 923
# Error downloading image 924
# Error downloading image 925
# Error downloading image 926
# Error downloading image 927
# Error downloading image 928
# Error downloading image 929
# Error downloading image 930
# Error downloading image 931
# Error downloading image 932
# Error downloading image 933
# Error downloading image 934
# Error downloading image 935
# Error downloading image 936
# Error downloading image 937
# Error downloading image 938
#   4%|▍         | 1038/25000 [36:05<07:45, 51.48it/s]
# Error downloading image 939
# Error downloading image 940
# Error downloading image 941
# Error downloading image 942
# Error downloading image 943
# Error downloading image 944
# Error downloading image 945
# Error downloading image 946
# Error downloading image 947
# Error downloading image 948
# Error downloading image 949
# Error downloading image 950
# Error downloading image 951
# Error downloading image 952
# Error downloading image 953
# Error downloading image 954
# Error downloading image 955
# Error downloading image 956
# Error downloading image 957
# Error downloading image 958
# Error downloading image 959
# Error downloading image 960
# Error downloading image 961
# Error downloading image 962
# Error downloading image 963
# Error downloading image 964
# Error downloading image 965
# Error downloading image 966
# Error downloading image 967
# Error downloading image 968
# Error downloading image 969
# Error downloading image 970
# Error downloading image 971
# Error downloading image 972
# Error downloading image 973
# Error downloading image 974
# Error downloading image 975
# Error downloading image 976
# Error downloading image 977
# Error downloading image 978
# Error downloading image 979
# Error downloading image 980
# Error downloading image 981
# Error downloading image 982
# Error downloading image 983
# Error downloading image 984
# Error downloading image 985
# Error downloading image 986
# Error downloading image 987
# Error downloading image 988
# Error downloading image 989
# Error downloading image 990
# Error downloading image 991
# Error downloading image 992
# Error downloading image 993
# Error downloading image 994
# Error downloading image 995
# Error downloading image 996
# Error downloading image 997
# Error downloading image 998
# Error downloading image 999
# Error downloading image 1000
# Error downloading image 1001
# Error downloading image 1002
# Error downloading image 1003
# Error downloading image 1004
# Error downloading image 1005
# Error downloading image 1006
# Error downloading image 1007
# Error downloading image 1008
# Error downloading image 1009
# Error downloading image 1010
# Error downloading image 1011
# Error downloading image 1012
# Error downloading image 1013
# Error downloading image 1014
# Error downloading image 1015
# Error downloading image 1016
# Error downloading image 1017
# Error downloading image 1018
# Error downloading image 1019
# Error downloading image 1020
# Error downloading image 1021
# Error downloading image 1022
# Error downloading image 1023
# Error downloading image 1024
# Error downloading image 1025
# Error downloading image 1026
# Error downloading image 1027
# Error downloading image 1028
# Error downloading image 1029
# Error downloading image 1030
# Error downloading image 1031
# Error downloading image 1032
# Error downloading image 1033
# Error downloading image 1034
# Error downloading image 1035
# Error downloading image 1036
# Error downloading image 1037
# Error downloading image 1038
# Error downloading image 1039
#   5%|▍         | 1145/25000 [36:05<03:48, 104.37it/s]
# Error downloading image 1040
# Error downloading image 1041
# Error downloading image 1042
# Error downloading image 1043
# Error downloading image 1044
# Error downloading image 1045
# Error downloading image 1046
# Error downloading image 1047
# Error downloading image 1048
# Error downloading image 1049
# Error downloading image 1050
# Error downloading image 1051
# Error downloading image 1052
# Error downloading image 1053
# Error downloading image 1054
# Error downloading image 1055
# Error downloading image 1056
# Error downloading image 1057
# Error downloading image 1058
# Error downloading image 1059
# Error downloading image 1060
# Error downloading image 1061
# Error downloading image 1062
# Error downloading image 1063
# Error downloading image 1064
# Error downloading image 1065
# Error downloading image 1066
# Error downloading image 1067
# Error downloading image 1068
# Error downloading image 1069
# Error downloading image 1070
# Error downloading image 1071
# Error downloading image 1072
# Error downloading image 1073
# Error downloading image 1074
# Error downloading image 1075
# Error downloading image 1076
# Error downloading image 1077
# Error downloading image 1078
# Error downloading image 1079
# Error downloading image 1080
# Error downloading image 1081
# Error downloading image 1082
# Error downloading image 1083
# Error downloading image 1084
# Error downloading image 1085
# Error downloading image 1086
# Error downloading image 1087
# Error downloading image 1088
# Error downloading image 1089
# Error downloading image 1090
# Error downloading image 1091
# Error downloading image 1092
# Error downloading image 1093
# Error downloading image 1094
# Error downloading image 1095
# Error downloading image 1096
# Error downloading image 1097
# Error downloading image 1098
# Error downloading image 1099
# Error downloading image 1100
# Error downloading image 1101
# Error downloading image 1102
# Error downloading image 1103
# Error downloading image 1104
# Error downloading image 1105
# Error downloading image 1106
# Error downloading image 1107
# Error downloading image 1108
# Error downloading image 1109
# Error downloading image 1110
# Error downloading image 1111
# Error downloading image 1112
# Error downloading image 1113
# Error downloading image 1114
# Error downloading image 1115
# Error downloading image 1116
# Error downloading image 1117
# Error downloading image 1118
# Error downloading image 1119
# Error downloading image 1120
# Error downloading image 1121
# Error downloading image 1122
# Error downloading image 1123
# Error downloading image 1124
# Error downloading image 1125
# Error downloading image 1126
# Error downloading image 1127
# Error downloading image 1128
# Error downloading image 1129
# Error downloading image 1130
# Error downloading image 1131
# Error downloading image 1132
# Error downloading image 1133
# Error downloading image 1134
# Error downloading image 1135
# Error downloading image 1136
# Error downloading image 1137
# Error downloading image 1138
# Error downloading image 1139
# Error downloading image 1140
# Error downloading image 1141
# Error downloading image 1142
# Error downloading image 1143
# Error downloading image 1144
# Error downloading image 1145
# Error downloading image 1146
# Error downloading image 1147
#   5%|▌         | 1252/25000 [36:06<02:10, 182.04it/s]
# Error downloading image 1148
# Error downloading image 1149
# Error downloading image 1150
# Error downloading image 1151
# Error downloading image 1152
# Error downloading image 1153
# Error downloading image 1154
# Error downloading image 1155
# Error downloading image 1156
# Error downloading image 1157
# Error downloading image 1158
# Error downloading image 1159
# Error downloading image 1160
# Error downloading image 1161
# Error downloading image 1162
# Error downloading image 1163
# Error downloading image 1164
# Error downloading image 1165
# Error downloading image 1166
# Error downloading image 1167
# Error downloading image 1168
# Error downloading image 1169
# Error downloading image 1170
# Error downloading image 1171
# Error downloading image 1172
# Error downloading image 1173
# Error downloading image 1174
# Error downloading image 1175
# Error downloading image 1176
# Error downloading image 1177
# Error downloading image 1178
# Error downloading image 1179
# Error downloading image 1180
# Error downloading image 1181
# Error downloading image 1182
# Error downloading image 1183
# Error downloading image 1184
# Error downloading image 1185
# Error downloading image 1186
# Error downloading image 1187
# Error downloading image 1188
# Error downloading image 1189
# Error downloading image 1190
# Error downloading image 1191
# Error downloading image 1192
# Error downloading image 1193
# Error downloading image 1194
# Error downloading image 1195
# Error downloading image 1196
# Error downloading image 1197
# Error downloading image 1198
# Error downloading image 1199
# Error downloading image 1200
# Error downloading image 1201
# Error downloading image 1202
# Error downloading image 1203
# Error downloading image 1204
# Error downloading image 1205
# Error downloading image 1206
# Error downloading image 1207
# Error downloading image 1208
# Error downloading image 1209
# Error downloading image 1210
# Error downloading image 1211
# Error downloading image 1212
# Error downloading image 1213
# Error downloading image 1214
# Error downloading image 1215
# Error downloading image 1216
# Error downloading image 1217
# Error downloading image 1218
# Error downloading image 1219
# Error downloading image 1220
# Error downloading image 1221
# Error downloading image 1222
# Error downloading image 1223
# Error downloading image 1224
# Error downloading image 1225
# Error downloading image 1226
# Error downloading image 1227
# Error downloading image 1228
# Error downloading image 1229
# Error downloading image 1230
# Error downloading image 1231
# Error downloading image 1232
# Error downloading image 1233
# Error downloading image 1234
# Error downloading image 1235
# Error downloading image 1236
# Error downloading image 1237
# Error downloading image 1238
# Error downloading image 1239
# Error downloading image 1240
# Error downloading image 1241
# Error downloading image 1242
# Error downloading image 1243
# Error downloading image 1244
# Error downloading image 1245
# Error downloading image 1246
# Error downloading image 1247
# Error downloading image 1248
# Error downloading image 1249
# Error downloading image 1250
# Error downloading image 1251
# Error downloading image 1252
# Error downloading image 1253
# Error downloading image 1254
# Error downloading image 1255
# Error downloading image 1256
# Error downloading image 1257
# Error downloading image 1258
# Error downloading image 1259
# Error downloading image 1260
# Error downloading image 1261
# Error downloading image 1262
# Error downloading image 1263
#   5%|▌         | 1359/25000 [36:06<01:26, 273.80it/s]
# Error downloading image 1264
# Error downloading image 1265
# Error downloading image 1266
# Error downloading image 1267
# Error downloading image 1268
# Error downloading image 1269
# Error downloading image 1270
# Error downloading image 1271
# Error downloading image 1272
# Error downloading image 1273
# Error downloading image 1274
# Error downloading image 1275
# Error downloading image 1276
# Error downloading image 1277
# Error downloading image 1278
# Error downloading image 1279
# Error downloading image 1280
# Error downloading image 1281
# Error downloading image 1282
# Error downloading image 1283
# Error downloading image 1284
# Error downloading image 1285
# Error downloading image 1286
# Error downloading image 1287
# Error downloading image 1288
# Error downloading image 1289
# Error downloading image 1290
# Error downloading image 1291
# Error downloading image 1292
# Error downloading image 1293
# Error downloading image 1294
# Error downloading image 1295
# Error downloading image 1296
# Error downloading image 1297
# Error downloading image 1298
# Error downloading image 1299
# Error downloading image 1300
# Error downloading image 1301
# Error downloading image 1302
# Error downloading image 1303
# Error downloading image 1304
# Error downloading image 1305
# Error downloading image 1306
# Error downloading image 1307
# Error downloading image 1308
# Error downloading image 1309
# Error downloading image 1310
# Error downloading image 1311
# Error downloading image 1312
# Error downloading image 1313
# Error downloading image 1314
# Error downloading image 1315
# Error downloading image 1316
# Error downloading image 1317
# Error downloading image 1318
# Error downloading image 1319
# Error downloading image 1320
# Error downloading image 1321
# Error downloading image 1322
# Error downloading image 1323
# Error downloading image 1324
# Error downloading image 1325
# Error downloading image 1326
# Error downloading image 1327
# Error downloading image 1328
# Error downloading image 1329
# Error downloading image 1330
# Error downloading image 1331
# Error downloading image 1332
# Error downloading image 1333
# Error downloading image 1334
# Error downloading image 1335
# Error downloading image 1336
# Error downloading image 1337
# Error downloading image 1338
# Error downloading image 1339
# Error downloading image 1340
# Error downloading image 1341
# Error downloading image 1342
# Error downloading image 1343
# Error downloading image 1344
# Error downloading image 1345
# Error downloading image 1346
# Error downloading image 1347
# Error downloading image 1348
# Error downloading image 1349
# Error downloading image 1350
# Error downloading image 1351
# Error downloading image 1352
# Error downloading image 1353
# Error downloading image 1354
# Error downloading image 1355
# Error downloading image 1356
# Error downloading image 1357
# Error downloading image 1358
# Error downloading image 1359
# Error downloading image 1360
# Error downloading image 1361
# Error downloading image 1362
# Error downloading image 1363
# Error downloading image 1364
# Error downloading image 1365
# Error downloading image 1366
# Error downloading image 1367
# Error downloading image 1368
# Error downloading image 1369
# Error downloading image 1370
# Error downloading image 1371
# Error downloading image 1372
#   6%|▌         | 1461/25000 [36:06<01:08, 344.04it/s]
# Error downloading image 1373
# Error downloading image 1374
# Error downloading image 1375
# Error downloading image 1376
# Error downloading image 1377
# Error downloading image 1378
# Error downloading image 1379
# Error downloading image 1380
# Error downloading image 1381
# Error downloading image 1382
# Error downloading image 1383
# Error downloading image 1384
# Error downloading image 1385
# Error downloading image 1386
# Error downloading image 1387
# Error downloading image 1388
# Error downloading image 1389
# Error downloading image 1390
# Error downloading image 1391
# Error downloading image 1392
# Error downloading image 1393
# Error downloading image 1394
# Error downloading image 1395
# Error downloading image 1396
# Error downloading image 1397
# Error downloading image 1398
# Error downloading image 1399
# Error downloading image 1400
# Error downloading image 1401
# Error downloading image 1402
# Error downloading image 1403
# Error downloading image 1404
# Error downloading image 1405
# Error downloading image 1406
# Error downloading image 1407
# Error downloading image 1408
# Error downloading image 1409
# Error downloading image 1410
# Error downloading image 1411
# Error downloading image 1412
# Error downloading image 1413
# Error downloading image 1414
# Error downloading image 1415
# Error downloading image 1416
# Error downloading image 1417
# Error downloading image 1418
# Error downloading image 1419
# Error downloading image 1420
# Error downloading image 1421
# Error downloading image 1422
# Error downloading image 1423
# Error downloading image 1424
# Error downloading image 1425
# Error downloading image 1426
# Error downloading image 1427
# Error downloading image 1428
# Error downloading image 1429
# Error downloading image 1430
# Error downloading image 1431
# Error downloading image 1432
# Error downloading image 1433
# Error downloading image 1434
# Error downloading image 1435
# Error downloading image 1436
# Error downloading image 1437
# Error downloading image 1438
# Error downloading image 1439
# Error downloading image 1440
# Error downloading image 1441
# Error downloading image 1442
# Error downloading image 1443
# Error downloading image 1444
# Error downloading image 1445
# Error downloading image 1446
# Error downloading image 1447
# Error downloading image 1448
# Error downloading image 1449
# Error downloading image 1450
# Error downloading image 1451
# Error downloading image 1452
# Error downloading image 1453
# Error downloading image 1454
# Error downloading image 1455
# Error downloading image 1456
# Error downloading image 1457
# Error downloading image 1458
# Error downloading image 1459
# Error downloading image 1460
# Error downloading image 1461
# Error downloading image 1462
# Error downloading image 1463
# Error downloading image 1464
# Error downloading image 1465
# Error downloading image 1466
# Error downloading image 1467
# Error downloading image 1468
# Error downloading image 1469
# Error downloading image 1470
# Error downloading image 1471
#   6%|▌         | 1559/25000 [36:06<01:00, 387.17it/s]
# Error downloading image 1472
# Error downloading image 1473
# Error downloading image 1474
# Error downloading image 1475
# Error downloading image 1476
# Error downloading image 1477
# Error downloading image 1478
# Error downloading image 1479
# Error downloading image 1480
# Error downloading image 1481
# Error downloading image 1482
# Error downloading image 1483
# Error downloading image 1484
# Error downloading image 1485
# Error downloading image 1486
# Error downloading image 1487
# Error downloading image 1488
# Error downloading image 1489
# Error downloading image 1490
# Error downloading image 1491
# Error downloading image 1492
# Error downloading image 1493
# Error downloading image 1494
# Error downloading image 1495
# Error downloading image 1496
# Error downloading image 1497
# Error downloading image 1498
# Error downloading image 1499
# Error downloading image 1500
# Error downloading image 1501
# Error downloading image 1502
# Error downloading image 1503
# Error downloading image 1504
# Error downloading image 1505
# Error downloading image 1506
# Error downloading image 1507
# Error downloading image 1508
# Error downloading image 1509
# Error downloading image 1510
# Error downloading image 1511
# Error downloading image 1512
# Error downloading image 1513
# Error downloading image 1514
# Error downloading image 1515
# Error downloading image 1516
# Error downloading image 1517
# Error downloading image 1518
# Error downloading image 1519
# Error downloading image 1520
# Error downloading image 1521
# Error downloading image 1522
# Error downloading image 1523
# Error downloading image 1524
# Error downloading image 1525
# Error downloading image 1526
# Error downloading image 1527
# Error downloading image 1528
# Error downloading image 1529
# Error downloading image 1530
# Error downloading image 1531
# Error downloading image 1532
# Error downloading image 1533
# Error downloading image 1534
# Error downloading image 1535
# Error downloading image 1536
# Error downloading image 1537
# Error downloading image 1538
# Error downloading image 1539
# Error downloading image 1540
# Error downloading image 1541
# Error downloading image 1542
# Error downloading image 1543
# Error downloading image 1544
# Error downloading image 1545
# Error downloading image 1546
# Error downloading image 1547
# Error downloading image 1548
# Error downloading image 1549
# Error downloading image 1550
# Error downloading image 1551
# Error downloading image 1552
# Error downloading image 1553
# Error downloading image 1554
# Error downloading image 1555
# Error downloading image 1556
# Error downloading image 1557
# Error downloading image 1558
# Error downloading image 1559
# Error downloading image 1560
# Error downloading image 1561
# Error downloading image 1562
# Error downloading image 1563
# Error downloading image 1564
# Error downloading image 1565
# Error downloading image 1566
# Error downloading image 1567
# Error downloading image 1568
#   7%|▋         | 1670/25000 [36:06<00:50, 460.17it/s]
# Error downloading image 1569
# Error downloading image 1570
# Error downloading image 1571
# Error downloading image 1572
# Error downloading image 1573
# Error downloading image 1574
# Error downloading image 1575
# Error downloading image 1576
# Error downloading image 1577
# Error downloading image 1578
# Error downloading image 1579
# Error downloading image 1580
# Error downloading image 1581
# Error downloading image 1582
# Error downloading image 1583
# Error downloading image 1584
# Error downloading image 1585
# Error downloading image 1586
# Error downloading image 1587
# Error downloading image 1588
# Error downloading image 1589
# Error downloading image 1590
# Error downloading image 1591
# Error downloading image 1592
# Error downloading image 1593
# Error downloading image 1594
# Error downloading image 1595
# Error downloading image 1596
# Error downloading image 1597
# Error downloading image 1598
# Error downloading image 1599
# Error downloading image 1600
# Error downloading image 1601
# Error downloading image 1602
# Error downloading image 1603
# Error downloading image 1604
# Error downloading image 1605
# Error downloading image 1606
# Error downloading image 1607
# Error downloading image 1608
# Error downloading image 1609
# Error downloading image 1610
# Error downloading image 1611
# Error downloading image 1612
# Error downloading image 1613
# Error downloading image 1614
# Error downloading image 1615
# Error downloading image 1616
# Error downloading image 1617
# Error downloading image 1618
# Error downloading image 1619
# Error downloading image 1620
# Error downloading image 1621
# Error downloading image 1622
# Error downloading image 1623
# Error downloading image 1624
# Error downloading image 1625
# Error downloading image 1626
# Error downloading image 1627
# Error downloading image 1628
# Error downloading image 1629
# Error downloading image 1630
# Error downloading image 1631
# Error downloading image 1632
# Error downloading image 1633
# Error downloading image 1634
# Error downloading image 1635
# Error downloading image 1636
# Error downloading image 1637
# Error downloading image 1638
# Error downloading image 1639
# Error downloading image 1640
# Error downloading image 1641
# Error downloading image 1642
# Error downloading image 1643
# Error downloading image 1644
# Error downloading image 1645
# Error downloading image 1646
# Error downloading image 1647
# Error downloading image 1648
# Error downloading image 1649
# Error downloading image 1650
# Error downloading image 1651
# Error downloading image 1652
# Error downloading image 1653
# Error downloading image 1654
# Error downloading image 1655
# Error downloading image 1656
# Error downloading image 1657
# Error downloading image 1658
# Error downloading image 1659
# Error downloading image 1660
# Error downloading image 1661
# Error downloading image 1662
# Error downloading image 1663
# Error downloading image 1664
# Error downloading image 1665
# Error downloading image 1666
# Error downloading image 1667
# Error downloading image 1668
# Error downloading image 1669
# Error downloading image 1670
# Error downloading image 1671
# Error downloading image 1672
# Error downloading image 1673
# Error downloading image 1674
# Error downloading image 1675
# Error downloading image 1676
# Error downloading image 1677
# Error downloading image 1678
# Error downloading image 1679
#   7%|▋         | 1774/25000 [36:07<00:49, 469.03it/s]
# Error downloading image 1680
# Error downloading image 1681
# Error downloading image 1682
# Error downloading image 1683
# Error downloading image 1684
# Error downloading image 1685
# Error downloading image 1686
# Error downloading image 1687
# Error downloading image 1688
# Error downloading image 1689
# Error downloading image 1690
# Error downloading image 1691
# Error downloading image 1692
# Error downloading image 1693
# Error downloading image 1694
# Error downloading image 1695
# Error downloading image 1696
# Error downloading image 1697
# Error downloading image 1698
# Error downloading image 1699
# Error downloading image 1700
# Error downloading image 1701
# Error downloading image 1702
# Error downloading image 1703
# Error downloading image 1704
# Error downloading image 1705
# Error downloading image 1706
# Error downloading image 1707
# Error downloading image 1708
# Error downloading image 1709
# Error downloading image 1710
# Error downloading image 1711
# Error downloading image 1712
# Error downloading image 1713
# Error downloading image 1714
# Error downloading image 1715
# Error downloading image 1716
# Error downloading image 1717
# Error downloading image 1718
# Error downloading image 1719
# Error downloading image 1720
# Error downloading image 1721
# Error downloading image 1722
# Error downloading image 1723
# Error downloading image 1724
# Error downloading image 1725
# Error downloading image 1726
# Error downloading image 1727
# Error downloading image 1728
# Error downloading image 1729
# Error downloading image 1730
# Error downloading image 1731
# Error downloading image 1732
# Error downloading image 1733
# Error downloading image 1734
# Error downloading image 1735
# Error downloading image 1736
# Error downloading image 1737
# Error downloading image 1738
# Error downloading image 1739
# Error downloading image 1740
# Error downloading image 1741
# Error downloading image 1742
# Error downloading image 1743
# Error downloading image 1744
# Error downloading image 1745
# Error downloading image 1746
# Error downloading image 1747
# Error downloading image 1748
# Error downloading image 1749
# Error downloading image 1750
# Error downloading image 1751
# Error downloading image 1752
# Error downloading image 1753
# Error downloading image 1754
# Error downloading image 1755
# Error downloading image 1756
# Error downloading image 1757
# Error downloading image 1758
# Error downloading image 1759
# Error downloading image 1760
# Error downloading image 1761
# Error downloading image 1762
# Error downloading image 1763
# Error downloading image 1764
# Error downloading image 1765
# Error downloading image 1766
# Error downloading image 1767
# Error downloading image 1768
# Error downloading image 1769
# Error downloading image 1770
# Error downloading image 1771
# Error downloading image 1772
# Error downloading image 1773
# Error downloading image 1774
# Error downloading image 1775
# Error downloading image 1776
# Error downloading image 1777
# Error downloading image 1778
# Error downloading image 1779
# Error downloading image 1780
# Error downloading image 1781
# Error downloading image 1782
# Error downloading image 1783
#   8%|▊         | 1881/25000 [36:07<00:46, 499.79it/s]
# Error downloading image 1784
# Error downloading image 1785
# Error downloading image 1786
# Error downloading image 1787
# Error downloading image 1788
# Error downloading image 1789
# Error downloading image 1790
# Error downloading image 1791
# Error downloading image 1792
# Error downloading image 1793
# Error downloading image 1794
# Error downloading image 1795
# Error downloading image 1796
# Error downloading image 1797
# Error downloading image 1798
# Error downloading image 1799
# Error downloading image 1800
# Error downloading image 1801
# Error downloading image 1802
# Error downloading image 1803
# Error downloading image 1804
# Error downloading image 1805
# Error downloading image 1806
# Error downloading image 1807
# Error downloading image 1808
# Error downloading image 1809
# Error downloading image 1810
# Error downloading image 1811
# Error downloading image 1812
# Error downloading image 1813
# Error downloading image 1814
# Error downloading image 1815
# Error downloading image 1816
# Error downloading image 1817
# Error downloading image 1818
# Error downloading image 1819
# Error downloading image 1820
# Error downloading image 1821
# Error downloading image 1822
# Error downloading image 1823
# Error downloading image 1824
# Error downloading image 1825
# Error downloading image 1826
# Error downloading image 1827
# Error downloading image 1828
# Error downloading image 1829
# Error downloading image 1830
# Error downloading image 1831
# Error downloading image 1832
# Error downloading image 1833
# Error downloading image 1834
# Error downloading image 1835
# Error downloading image 1836
# Error downloading image 1837
# Error downloading image 1838
# Error downloading image 1839
# Error downloading image 1840
# Error downloading image 1841
# Error downloading image 1842
# Error downloading image 1843
# Error downloading image 1844
# Error downloading image 1845
# Error downloading image 1846
# Error downloading image 1847
# Error downloading image 1848
# Error downloading image 1849
# Error downloading image 1850
# Error downloading image 1851
# Error downloading image 1852
# Error downloading image 1853
# Error downloading image 1854
# Error downloading image 1855
# Error downloading image 1856
# Error downloading image 1857
# Error downloading image 1858
# Error downloading image 1859
# Error downloading image 1860
# Error downloading image 1861
# Error downloading image 1862
# Error downloading image 1863
# Error downloading image 1864
# Error downloading image 1865
# Error downloading image 1866
# Error downloading image 1867
# Error downloading image 1868
# Error downloading image 1869
# Error downloading image 1870
# Error downloading image 1871
# Error downloading image 1872
# Error downloading image 1873
# Error downloading image 1874
# Error downloading image 1875
# Error downloading image 1876
# Error downloading image 1877
# Error downloading image 1878
# Error downloading image 1879
# Error downloading image 1880
# Error downloading image 1881
# Error downloading image 1882
# Error downloading image 1883
# Error downloading image 1884
# Error downloading image 1885
# Error downloading image 1886
# Error downloading image 1887
# Error downloading image 1888
# Error downloading image 1889
# Error downloading image 1890
# Error downloading image 1891
# Error downloading image 1892
# Error downloading image 1893
# Error downloading image 1894
# Error downloading image 1895
# Error downloading image 1896
# Error downloading image 1897
# Error downloading image 1898
# Error downloading image 1899
#   8%|▊         | 1990/25000 [36:07<00:43, 523.06it/s]
# Error downloading image 1900
# Error downloading image 1901
# Error downloading image 1902
# Error downloading image 1903
# Error downloading image 1904
# Error downloading image 1905
# Error downloading image 1906
# Error downloading image 1907
# Error downloading image 1908
# Error downloading image 1909
# Error downloading image 1910
# Error downloading image 1911
# Error downloading image 1912
# Error downloading image 1913
# Error downloading image 1914
# Error downloading image 1915
# Error downloading image 1916
# Error downloading image 1917
# Error downloading image 1918
# Error downloading image 1919
# Error downloading image 1920
# Error downloading image 1921
# Error downloading image 1922
# Error downloading image 1923
# Error downloading image 1924
# Error downloading image 1925
# Error downloading image 1926
# Error downloading image 1927
# Error downloading image 1928
# Error downloading image 1929
# Error downloading image 1930
# Error downloading image 1931
# Error downloading image 1932
# Error downloading image 1933
# Error downloading image 1934
# Error downloading image 1935
# Error downloading image 1936
# Error downloading image 1937
# Error downloading image 1938
# Error downloading image 1939
# Error downloading image 1940
# Error downloading image 1941
# Error downloading image 1942
# Error downloading image 1943
# Error downloading image 1944
# Error downloading image 1945
# Error downloading image 1946
# Error downloading image 1947
# Error downloading image 1948
# Error downloading image 1949
# Error downloading image 1950
# Error downloading image 1951
# Error downloading image 1952
# Error downloading image 1953
# Error downloading image 1954
# Error downloading image 1955
# Error downloading image 1956
# Error downloading image 1957
# Error downloading image 1958
# Error downloading image 1959
# Error downloading image 1960
# Error downloading image 1961
# Error downloading image 1962
# Error downloading image 1963
# Error downloading image 1964
# Error downloading image 1965
# Error downloading image 1966
# Error downloading image 1967
# Error downloading image 1968
# Error downloading image 1969
# Error downloading image 1970
# Error downloading image 1971
# Error downloading image 1972
# Error downloading image 1973
# Error downloading image 1974
# Error downloading image 1975
# Error downloading image 1976
# Error downloading image 1977
# Error downloading image 1978
# Error downloading image 1979
# Error downloading image 1980
# Error downloading image 1981
# Error downloading image 1982
# Error downloading image 1983
# Error downloading image 1984
# Error downloading image 1985
# Error downloading image 1986
# Error downloading image 1987
# Error downloading image 1988
# Error downloading image 1989
# Error downloading image 1990
# Error downloading image 1991
# Error downloading image 1992
# Error downloading image 1993
# Error downloading image 1994
# Error downloading image 1995
# Error downloading image 1996
# Error downloading image 1997
# Error downloading image 1998
# Error downloading image 1999
# Error downloading image 2000
# Error downloading image 2001
# Error downloading image 2002
# Error downloading image 2003
# Error downloading image 2004
# Error downloading image 2005
# Error downloading image 2006
# Error downloading image 2007
# Error downloading image 2008
# Error downloading image 2009
# Error downloading image 2010
# Error downloading image 2011
# Error downloading image 2012
# Error downloading image 2013
# Error downloading image 2014
# Error downloading image 2015
# Error downloading image 2016
#   8%|▊         | 2097/25000 [36:07<00:43, 521.28it/s]
# Error downloading image 2017
# Error downloading image 2018
# Error downloading image 2019
# Error downloading image 2020
# Error downloading image 2021
# Error downloading image 2022
# Error downloading image 2023
# Error downloading image 2024
# Error downloading image 2025
# Error downloading image 2026
# Error downloading image 2027
# Error downloading image 2028
# Error downloading image 2029
# Error downloading image 2030
# Error downloading image 2031
# Error downloading image 2032
# Error downloading image 2033
# Error downloading image 2034
# Error downloading image 2035
# Error downloading image 2036
# Error downloading image 2037
# Error downloading image 2038
# Error downloading image 2039
# Error downloading image 2040
# Error downloading image 2041
# Error downloading image 2042
# Error downloading image 2043
# Error downloading image 2044
# Error downloading image 2045
# Error downloading image 2046
# Error downloading image 2047
# Error downloading image 2048
# Error downloading image 2049
# Error downloading image 2050
# Error downloading image 2051
# Error downloading image 2052
# Error downloading image 2053
# Error downloading image 2054
# Error downloading image 2055
# Error downloading image 2056
# Error downloading image 2057
# Error downloading image 2058
# Error downloading image 2059
# Error downloading image 2060
# Error downloading image 2061
# Error downloading image 2062
# Error downloading image 2063
# Error downloading image 2064
# Error downloading image 2065
# Error downloading image 2066
# Error downloading image 2067
# Error downloading image 2068
# Error downloading image 2069
# Error downloading image 2070
# Error downloading image 2071
# Error downloading image 2072
# Error downloading image 2073
# Error downloading image 2074
# Error downloading image 2075
# Error downloading image 2076
# Error downloading image 2077
# Error downloading image 2078
# Error downloading image 2079
# Error downloading image 2080
# Error downloading image 2081
# Error downloading image 2082
# Error downloading image 2083
# Error downloading image 2084
# Error downloading image 2085
# Error downloading image 2086
# Error downloading image 2087
# Error downloading image 2088
# Error downloading image 2089
# Error downloading image 2090
# Error downloading image 2091
# Error downloading image 2092
# Error downloading image 2093
# Error downloading image 2094
# Error downloading image 2095
# Error downloading image 2096
# Error downloading image 2097
# Error downloading image 2098
# Error downloading image 2099
# Error downloading image 2100
# Error downloading image 2101
# Error downloading image 2102
# Error downloading image 2103
# Error downloading image 2104
# Error downloading image 2105
# Error downloading image 2106
# Error downloading image 2107
# Error downloading image 2108
# Error downloading image 2109
# Error downloading image 2110
# Error downloading image 2111
# Error downloading image 2112
# Error downloading image 2113
# Error downloading image 2114
# Error downloading image 2115
# Error downloading image 2116
# Error downloading image 2117
# Error downloading image 2118
# Error downloading image 2119
# Error downloading image 2120
# Error downloading image 2121
# Error downloading image 2122
#   9%|▉         | 2207/25000 [36:07<00:42, 532.76it/s]
# Error downloading image 2123
# Error downloading image 2124
# Error downloading image 2125
# Error downloading image 2126
# Error downloading image 2127
# Error downloading image 2128
# Error downloading image 2129
# Error downloading image 2130
# Error downloading image 2131
# Error downloading image 2132
# Error downloading image 2133
# Error downloading image 2134
# Error downloading image 2135
# Error downloading image 2136
# Error downloading image 2137
# Error downloading image 2138
# Error downloading image 2139
# Error downloading image 2140
# Error downloading image 2141
# Error downloading image 2142
# Error downloading image 2143
# Error downloading image 2144
# Error downloading image 2145
# Error downloading image 2146
# Error downloading image 2147
# Error downloading image 2148
# Error downloading image 2149
# Error downloading image 2150
# Error downloading image 2151
# Error downloading image 2152
# Error downloading image 2153
# Error downloading image 2154
# Error downloading image 2155
# Error downloading image 2156
# Error downloading image 2157
# Error downloading image 2158
# Error downloading image 2159
# Error downloading image 2160
# Error downloading image 2161
# Error downloading image 2162
# Error downloading image 2163
# Error downloading image 2164
# Error downloading image 2165
# Error downloading image 2166
# Error downloading image 2167
# Error downloading image 2168
# Error downloading image 2169
# Error downloading image 2170
# Error downloading image 2171
# Error downloading image 2172
# Error downloading image 2173
# Error downloading image 2174
# Error downloading image 2175
# Error downloading image 2176
# Error downloading image 2177
# Error downloading image 2178
# Error downloading image 2179
# Error downloading image 2180
# Error downloading image 2181
# Error downloading image 2182
# Error downloading image 2183
# Error downloading image 2184
# Error downloading image 2185
# Error downloading image 2186
# Error downloading image 2187
# Error downloading image 2188
# Error downloading image 2189
# Error downloading image 2190
# Error downloading image 2191
# Error downloading image 2192
# Error downloading image 2193
# Error downloading image 2194
# Error downloading image 2195
# Error downloading image 2196
# Error downloading image 2197
# Error downloading image 2198
# Error downloading image 2199
# Error downloading image 2200
# Error downloading image 2201
# Error downloading image 2202
# Error downloading image 2203
# Error downloading image 2204
# Error downloading image 2205
# Error downloading image 2206
# Error downloading image 2207
# Error downloading image 2208
# Error downloading image 2209
# Error downloading image 2210
# Error downloading image 2211
# Error downloading image 2212
# Error downloading image 2213
# Error downloading image 2214
# Error downloading image 2215
# Error downloading image 2216
# Error downloading image 2217
# Error downloading image 2218
# Error downloading image 2219
# Error downloading image 2220
# Error downloading image 2221
# Error downloading image 2222
# Error downloading image 2223
# Error downloading image 2224
# Error downloading image 2225
# Error downloading image 2226
# Error downloading image 2227
# Error downloading image 2228
# Error downloading image 2229
# Error downloading image 2230
# Error downloading image 2231
# Error downloading image 2232
# Error downloading image 2233
# Error downloading image 2234
# Error downloading image 2235
# Error downloading image 2236
#   9%|▉         | 2318/25000 [36:08<00:41, 543.29it/s]
# Error downloading image 2237
# Error downloading image 2238
# Error downloading image 2239
# Error downloading image 2240
# Error downloading image 2241
# Error downloading image 2242
# Error downloading image 2243
# Error downloading image 2244
# Error downloading image 2245
# Error downloading image 2246
# Error downloading image 2247
# Error downloading image 2248
# Error downloading image 2249
# Error downloading image 2250
# Error downloading image 2251
# Error downloading image 2252
# Error downloading image 2253
# Error downloading image 2254
# Error downloading image 2255
# Error downloading image 2256
# Error downloading image 2257
# Error downloading image 2258
# Error downloading image 2259
# Error downloading image 2260
# Error downloading image 2261
# Error downloading image 2262
# Error downloading image 2263
# Error downloading image 2264
# Error downloading image 2265
# Error downloading image 2266
# Error downloading image 2267
# Error downloading image 2268
# Error downloading image 2269
# Error downloading image 2270
# Error downloading image 2271
# Error downloading image 2272
# Error downloading image 2273
# Error downloading image 2274
# Error downloading image 2275
# Error downloading image 2276
# Error downloading image 2277
# Error downloading image 2278
# Error downloading image 2279
# Error downloading image 2280
# Error downloading image 2281
# Error downloading image 2282
# Error downloading image 2283
# Error downloading image 2284
# Error downloading image 2285
# Error downloading image 2286
# Error downloading image 2287
# Error downloading image 2288
# Error downloading image 2289
# Error downloading image 2290
# Error downloading image 2291
# Error downloading image 2292
# Error downloading image 2293
# Error downloading image 2294
# Error downloading image 2295
# Error downloading image 2296
# Error downloading image 2297
# Error downloading image 2298
# Error downloading image 2299
# Error downloading image 2300
# Error downloading image 2301
# Error downloading image 2302
# Error downloading image 2303
# Error downloading image 2304
# Error downloading image 2305
# Error downloading image 2306
# Error downloading image 2307
# Error downloading image 2308
# Error downloading image 2309
# Error downloading image 2310
# Error downloading image 2311
# Error downloading image 2312
# Error downloading image 2313
# Error downloading image 2314
# Error downloading image 2315
# Error downloading image 2316
# Error downloading image 2317
# Error downloading image 2318
# Error downloading image 2319
# Error downloading image 2320
# Error downloading image 2321
# Error downloading image 2322
# Error downloading image 2323
# Error downloading image 2324
# Error downloading image 2325
# Error downloading image 2326
# Error downloading image 2327
# Error downloading image 2328
# Error downloading image 2329
# Error downloading image 2330
# Error downloading image 2331
# Error downloading image 2332
# Error downloading image 2333
# Error downloading image 2334
# Error downloading image 2335
# Error downloading image 2336
# Error downloading image 2337
# Error downloading image 2338
# Error downloading image 2339
# Error downloading image 2340
# Error downloading image 2341
# Error downloading image 2342
# Error downloading image 2343
# Error downloading image 2344
# Error downloading image 2345
# Error downloading image 2346
# Error downloading image 2347
# Error downloading image 2348
# Error downloading image 2349
# Error downloading image 2350
# Error downloading image 2351
# Error downloading image 2352
# Error downloading image 2353
# Error downloading image 2354
#  10%|▉         | 2429/25000 [36:08<00:41, 544.79it/s]
# Error downloading image 2355
# Error downloading image 2356
# Error downloading image 2357
# Error downloading image 2358
# Error downloading image 2359
# Error downloading image 2360
# Error downloading image 2361
# Error downloading image 2362
# Error downloading image 2363
# Error downloading image 2364
# Error downloading image 2365
# Error downloading image 2366
# Error downloading image 2367
# Error downloading image 2368
# Error downloading image 2369
# Error downloading image 2370
# Error downloading image 2371
# Error downloading image 2372
# Error downloading image 2373
# Error downloading image 2374
# Error downloading image 2375
# Error downloading image 2376
# Error downloading image 2377
# Error downloading image 2378
# Error downloading image 2379
# ...
# Error downloading image 6407
# Error downloading image 6408
# Error downloading image 6409
# Error downloading image 6410
# Error downloading image 6411
# Error downloading image 6412
# Error downloading image 6413
# Error downloading image 6414
# Error downloading image 6415
# Error downloading image 6416
# Error downloading image 6417
# Error downloading image 6418
# Error downloading image 6419
# Error downloading image 6420
# Error downloading image 6421
# Error downloading image 6422
# Error downloading image 6423
# Error downloading image 6424
# Error downloading image 6425
# Error downloading image 6426
# Error downloading image 6427
# Error downloading image 6428
# Error downloading image 6429
# Error downloading image 6430
# Error downloading image 6431
# Error downloading image 6432
# Error downloading image 6433
# Error downloading image 6434
# Error downloading image 6435
# Error downloading image 6436
# Error downloading image 6437
# Error downloading image 6438
# Error downloading image 6439
# Error downloading image 6440
# Error downloading image 6441
# Error downloading image 6442
# Error downloading image 6443
# Error downloading image 6444
# Error downloading image 6445
# Error downloading image 6446
# Error downloading image 6447
# Error downloading image 6448
# Error downloading image 6449
# Error downloading image 6450
# Error downloading image 6451
# Error downloading image 6452
# Error downloading image 6453
# Error downloading image 6454
# Error downloading image 6455
# Error downloading image 6456
# Error downloading image 6457
# Error downloading image 6458
# Error downloading image 6459
# Error downloading image 6460
# Error downloading image 6461
# Error downloading image 6462
# Error downloading image 6463
# Error downloading image 6464
# Error downloading image 6465
# Error downloading image 6466
# Error downloading image 6467
# Error downloading image 6468
# Error downloading image 6469
# Error downloading image 6470
# Error downloading image 6471
# Error downloading image 6472
# Error downloading image 6473
# Error downloading image 6474
# Error downloading image 6475
# Error downloading image 6476
# Error downloading image 6477
# Error downloading image 6478
# Error downloading image 6479
# Error downloading image 6480
# Error downloading image 6481
# Error downloading image 6482
#  26%|██▋       | 6571/25000 [36:16<00:34, 530.92it/s]
# Error downloading image 6483
# Error downloading image 6484
# Error downloading image 6485
# Error downloading image 6486
# Error downloading image 6487
# Error downloading image 6488
# Error downloading image 6489
# Error downloading image 6490
# Error downloading image 6491
# Error downloading image 6492
# Error downloading image 6493
# Error downloading image 6494
# Error downloading image 6495
# Error downloading image 6496
# Error downloading image 6497
# Error downloading image 6498
# Error downloading image 6499
# Error downloading image 6500
# Error downloading image 6501
# Error downloading image 6502
# Error downloading image 6503
# Error downloading image 6504
# Error downloading image 6505
# Error downloading image 6506
# Error downloading image 6507
# Error downloading image 6508
# Error downloading image 6509
# Error downloading image 6510
# Error downloading image 6511
# Error downloading image 6512
# Error downloading image 6513
# Error downloading image 6514
# Error downloading image 6515
# Error downloading image 6516
# Error downloading image 6517
# Error downloading image 6518
# Error downloading image 6519
# Error downloading image 6520
# Error downloading image 6521
# Error downloading image 6522
# Error downloading image 6523
# Error downloading image 6524
# Error downloading image 6525
# Error downloading image 6526
# Error downloading image 6527
# Error downloading image 6528
# Error downloading image 6529
# Error downloading image 6530
# Error downloading image 6531
# Error downloading image 6532
# Error downloading image 6533
# Error downloading image 6534
# Error downloading image 6535
# Error downloading image 6536
# Error downloading image 6537
# Error downloading image 6538
# Error downloading image 6539
# Error downloading image 6540
# Error downloading image 6541
# Error downloading image 6542
# Error downloading image 6543
# Error downloading image 6544
# Error downloading image 6545
# Error downloading image 6546
# Error downloading image 6547
# Error downloading image 6548
# Error downloading image 6549
# Error downloading image 6550
# Error downloading image 6551
# Error downloading image 6552
# Error downloading image 6553
# Error downloading image 6554
# Error downloading image 6555
# Error downloading image 6556
# Error downloading image 6557
# Error downloading image 6558
# Error downloading image 6559
# Error downloading image 6560
# Error downloading image 6561
# Error downloading image 6562
# Error downloading image 6563
# Error downloading image 6564
# Error downloading image 6565
# Error downloading image 6566
# Error downloading image 6567
# Error downloading image 6568
# Error downloading image 6569
# Error downloading image 6570
# Error downloading image 6571
# Error downloading image 6572
# Error downloading image 6573
# Error downloading image 6574
# Error downloading image 6575
# Error downloading image 6576
# Error downloading image 6577
# Error downloading image 6578
# Error downloading image 6579
# Error downloading image 6580
# Error downloading image 6581
# Error downloading image 6582
# Error downloading image 6583
# Error downloading image 6584
# Error downloading image 6585
# Error downloading image 6586
# Error downloading image 6587
# Error downloading image 6588
# Error downloading image 6589
# Error downloading image 6590
#  27%|██▋       | 6680/25000 [36:16<00:34, 535.64it/s]
# Error downloading image 6591
# Error downloading image 6592
# Error downloading image 6593
# Error downloading image 6594
# Error downloading image 6595
# Error downloading image 6596
# Error downloading image 6597
# Error downloading image 6598
# Error downloading image 6599
# Error downloading image 6600
# Error downloading image 6601
# Error downloading image 6602
# Error downloading image 6603
# Error downloading image 6604
# Error downloading image 6605
# Error downloading image 6606
# Error downloading image 6607
# Error downloading image 6608
# Error downloading image 6609
# Error downloading image 6610
# Error downloading image 6611
# Error downloading image 6612
# Error downloading image 6613
# Error downloading image 6614
# Error downloading image 6615
# Error downloading image 6616
# Error downloading image 6617
# Error downloading image 6618
# Error downloading image 6619
# Error downloading image 6620
# Error downloading image 6621
# Error downloading image 6622
# Error downloading image 6623
# Error downloading image 6624
# Error downloading image 6625
# Error downloading image 6626
# Error downloading image 6627
# Error downloading image 6628
# Error downloading image 6629
# Error downloading image 6630
# Error downloading image 6631
# Error downloading image 6632
# Error downloading image 6633
# Error downloading image 6634
# Error downloading image 6635
# Error downloading image 6636
# Error downloading image 6637
# Error downloading image 6638
# Error downloading image 6639
# Error downloading image 6640
# Error downloading image 6641
# Error downloading image 6642
# Error downloading image 6643
# Error downloading image 6644
# Error downloading image 6645
# Error downloading image 6646
# Error downloading image 6647
# Error downloading image 6648
# Error downloading image 6649
# Error downloading image 6650
# Error downloading image 6651
# Error downloading image 6652
# Error downloading image 6653
# Error downloading image 6654
# Error downloading image 6655
# Error downloading image 6656
# Error downloading image 6657
# Error downloading image 6658
# Error downloading image 6659
# Error downloading image 6660
# Error downloading image 6661
# Error downloading image 6662
# Error downloading image 6663
# Error downloading image 6664
# Error downloading image 6665
# Error downloading image 6666
# Error downloading image 6667
# Error downloading image 6668
# Error downloading image 6669
# Error downloading image 6670
# Error downloading image 6671
# Error downloading image 6672
# Error downloading image 6673
# Error downloading image 6674
# Error downloading image 6675
# Error downloading image 6676
# Error downloading image 6677
# Error downloading image 6678
# Error downloading image 6679
# Error downloading image 6680
# Error downloading image 6681
# Error downloading image 6682
# Error downloading image 6683
# Error downloading image 6684
# Error downloading image 6685
# Error downloading image 6686
# Error downloading image 6687
# Error downloading image 6688
# Error downloading image 6689
# Error downloading image 6690
# Error downloading image 6691
# Error downloading image 6692
# Error downloading image 6693
# Error downloading image 6694
# Error downloading image 6695
# Error downloading image 6696
# Error downloading image 6697
# Error downloading image 6698
# Error downloading image 6699
# Error downloading image 6700
# Error downloading image 6701
# Error downloading image 6702
# Error downloading image 6703
# Error downloading image 6704
#  27%|██▋       | 6788/25000 [36:16<00:34, 524.41it/s]
# Error downloading image 6705
# Error downloading image 6706
# Error downloading image 6707
# Error downloading image 6708
# Error downloading image 6709
# Error downloading image 6710
# Error downloading image 6711
# Error downloading image 6712
# Error downloading image 6713
# Error downloading image 6714
# Error downloading image 6715
# Error downloading image 6716
# Error downloading image 6717
# Error downloading image 6718
# Error downloading image 6719
# Error downloading image 6720
# Error downloading image 6721
# Error downloading image 6722
# Error downloading image 6723
# Error downloading image 6724
# Error downloading image 6725
# Error downloading image 6726
# Error downloading image 6727
# Error downloading image 6728
# Error downloading image 6729
# Error downloading image 6730
# Error downloading image 6731
# Error downloading image 6732
# Error downloading image 6733
# Error downloading image 6734
# Error downloading image 6735
# Error downloading image 6736
# Error downloading image 6737
# Error downloading image 6738
# Error downloading image 6739
# Error downloading image 6740
# Error downloading image 6741
# Error downloading image 6742
# Error downloading image 6743
# Error downloading image 6744
# Error downloading image 6745
# Error downloading image 6746
# Error downloading image 6747
# Error downloading image 6748
# Error downloading image 6749
# Error downloading image 6750
# Error downloading image 6751
# Error downloading image 6752
# Error downloading image 6753
# Error downloading image 6754
# Error downloading image 6755
# Error downloading image 6756
# Error downloading image 6757
# Error downloading image 6758
# Error downloading image 6759
# Error downloading image 6760
# Error downloading image 6761
# Error downloading image 6762
# Error downloading image 6763
# Error downloading image 6764
# Error downloading image 6765
# Error downloading image 6766
# Error downloading image 6767
# Error downloading image 6768
# Error downloading image 6769
# Error downloading image 6770
# Error downloading image 6771
# Error downloading image 6772
# Error downloading image 6773
# Error downloading image 6774
# Error downloading image 6775
# Error downloading image 6776
# Error downloading image 6777
# Error downloading image 6778
# Error downloading image 6779
# Error downloading image 6780
# Error downloading image 6781
# Error downloading image 6782
# Error downloading image 6783
# Error downloading image 6784
# Error downloading image 6785
# Error downloading image 6786
# Error downloading image 6787
# Error downloading image 6788
# Error downloading image 6789
# Error downloading image 6790
# Error downloading image 6791
# Error downloading image 6792
# Error downloading image 6793
# Error downloading image 6794
# Error downloading image 6795
# Error downloading image 6796
# Error downloading image 6797
# Error downloading image 6798
# Error downloading image 6799
# Error downloading image 6800
# Error downloading image 6801
# Error downloading image 6802
# Error downloading image 6803
# Error downloading image 6804
# Error downloading image 6805
# Error downloading image 6806
# Error downloading image 6807
# Error downloading image 6808
# Error downloading image 6809
# Error downloading image 6810
# Error downloading image 6811
# Error downloading image 6812
#  27%|██▋       | 6844/25000 [36:16<00:34, 533.11it/s]
# Error downloading image 6813
# Error downloading image 6814
# Error downloading image 6815
# Error downloading image 6816
# Error downloading image 6817
# Error downloading image 6818
# Error downloading image 6819
# Error downloading image 6820
# Error downloading image 6821
# Error downloading image 6822
# Error downloading image 6823
# Error downloading image 6824
# Error downloading image 6825
# Error downloading image 6826
# Error downloading image 6827
# Error downloading image 6828
# Error downloading image 6829
# Error downloading image 6830
# Error downloading image 6831
# Error downloading image 6832
# Error downloading image 6833
# Error downloading image 6834
# Error downloading image 6835
# Error downloading image 6836
# Error downloading image 6837
# Error downloading image 6838
# Error downloading image 6839
# Error downloading image 6840
# Error downloading image 6841
# Error downloading image 6842
# Error downloading image 6843
# Error downloading image 6844
# Error downloading image 6845
# Error downloading image 6846
# Error downloading image 6847
# Error downloading image 6848
# Error downloading image 6849
# Error downloading image 6850
# Error downloading image 6851
# Error downloading image 6852
# Error downloading image 6853
# Error downloading image 6854
# Error downloading image 6855
# Error downloading image 6856
# Error downloading image 6857
# Error downloading image 6858
# Error downloading image 6859
# Error downloading image 6860
# Error downloading image 6861
# Error downloading image 6862
# Error downloading image 6863
# Error downloading image 6864
# Error downloading image 6865
# Error downloading image 6866
# Error downloading image 6867
# Error downloading image 6868
# Error downloading image 6869
# Error downloading image 6870
# Error downloading image 6871
# Error downloading image 6872
# Error downloading image 6873
# Error downloading image 6874
# Error downloading image 6875
# Error downloading image 6876
# Error downloading image 6877
# Error downloading image 6878
# Error downloading image 6879
# Error downloading image 6880
# Error downloading image 6881
# Error downloading image 6882
# Error downloading image 6883
#  28%|██▊       | 6906/25000 [37:12<2:58:27,  1.69it/s]C:\Users\gowth\anaconda3\Lib\site-packages\PIL\Image.py:3432: DecompressionBombWarning: Image size (90671520 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#  29%|██▉       | 7254/25000 [47:55<1:57:14,  2.52it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 67
#      63             continue
#      65 if __name__ == "__main__":
#      66     # Download all images (or modify num_images to download fewer)
# ---> 67     download_images(num_images=None)
#
# Cell In[7], line 58, in download_images(num_images, output_dir, target_size)
#      56         if img.mode in ('RGBA', 'P'):
#      57             img = img.convert('RGB')
# ---> 58         img.thumbnail(target_size, Image.Resampling.LANCZOS)
#      59         img.save(output_path, 'JPEG', quality=85, optimize=True)
#      61 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2767, in Image.thumbnail(self, size, resample, reducing_gap)
#    2764         box = res[1]
#    2766 if self.size != final_size:
# -> 2767     im = self.resize(final_size, resample, box=box, reducing_gap=reducing_gap)
#    2769     self.im = im.im
#    2770     self._size = final_size
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2284, in Image.resize(self, size, resample, box, reducing_gap)
#    2281     im = im.resize(size, resample, box)
#    2282     return im.convert(self.mode)
# -> 2284 self.load()
#    2286 if reducing_gap is not None and resample != Resampling.NEAREST:
#    2287     factor_x = int((box[2] - box[0]) / size[0] / reducing_gap) or 1
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageFile.py:394, in ImageFile.load(self)
#     391         raise OSError(msg)
#     393 b = b + s
# --> 394 n, err_code = decoder.decode(b)
#     395 if n < 0:
#     396     break
#
# KeyboardInterrupt:
